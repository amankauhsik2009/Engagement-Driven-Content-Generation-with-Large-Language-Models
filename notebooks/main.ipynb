# %% [markdown]
# # Main Experiment Notebook
# This notebook runs the full pipeline step by step.

# %%
import sys, os
sys.path.append(os.path.abspath('../'))

from src.graph import create_graph
from src.visualization import plot_graph
from src.experiments import test_multiple_messages
from src.optimization import search_best_message, lightweight_ppo

# Step 1: Create graph
G, opinions = create_graph()

# Step 2: Visualize
plot_graph(G, opinions, title='Initial Network')

# Step 3: Test prompts
prompts = ['Climate action is', 'Future of AI is', 'Public policy must prioritize']
results = test_multiple_messages(G, opinions, prompts)
print(results)

# Step 4: Brute-force search
print(search_best_message(G, opinions))

# Step 5: PPO optimization
print(lightweight_ppo(G, opinions))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       4 from src.graph import create_graph
#       5 from src.visualization import plot_graph
# ----> 6 from src.experiments import test_multiple_messages
#       7 from src.optimization import search_best_message, lightweight_ppo
#       9 # Step 1: Create graph
#
# File ~/Downloads/project_commented/src/experiments.py:1
# ----> 1 from .llm import generate_post, get_sentiment_score
#       2 from .propagation import propagate
#       4 def test_multiple_messages(G, opinions, prompts):
#       5     # Try multiple prompts and compare influence spread
#
# File ~/Downloads/project_commented/src/llm.py:4
#       1 from transformers import pipeline
#       3 # Using lightweight GPT-2 just for generating sample text
# ----> 4 generator = pipeline("text-generation", model="gpt2")
#       6 # Sentiment model to convert text into numeric signal
#       7 sentiment_model = pipeline("sentiment-analysis")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/pipelines/__init__.py:797, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     792         raise ValueError(
#     793             'You cannot use both `pipeline(... dtype=..., model_kwargs={"dtype":...})` as those'
#     794             " arguments might conflict, use only one.)"
#     795         )
#     796 if dtype is not None:
# --> 797     if isinstance(dtype, str) and hasattr(torch, dtype):
#     798         dtype = getattr(torch, dtype)
#     799     model_kwargs["dtype"] = dtype
#
# NameError: name 'torch' is not defined
